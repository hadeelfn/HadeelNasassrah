# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
     
img = cv2.imread('images/ff.png') 
     
kernel = np.ones((11,11),np.float32)/25
dst = cv2.filter2D(img,-1,kernel)
     
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
     
img = cv2.imread('images/2.jpg') 
     
kernel = np.ones((11,11),np.float32)/25
dst = cv2.filter2D(img,-1,kernel)
     
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-13-f620d881adc8> in <module>()
#       6
#       7 kernel = np.ones((11,11),np.float32)/25
# ----> 8 dst = cv2.filter2D(img,-1,kernel)
#       9
#      10 plt.subplot(121),plt.imshow(img),plt.title('Original')
#
# error: C:\bld\opencv_1498171314629\work\opencv-3.2.0\modules\core\src\matrix.cpp:949: error: (-215) dims <= 2 && step[0] > 0 in function cv::Mat::locateROI

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
     
img = cv2.imread('images/ff.png') 
     
blur = cv2.blur(img,(11,11))

plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()
